# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1-1Ehz1QBrjYqfH6SITCbmn6B29CyCPqo': "data/images.npz",
        '1-OWMg8uy2bvuONw_0mmCMaEJBmckvxud': "data/train_data.npz",
        '1-GNpWqe4T1UTWY_QnvzJDU7-WCc1uDIL': "data/valid_data.npz",
        '1-Wk9OoipexkS8BlVR_1_TD3Ay1vgzAl-': "data/kpt.npy",
        '1-R8Ml635hqPaNNDhNUDspEZZJW2AzsnG': "data/misc_data.npz",
        '1-cXm7Q1m7pZQYlUKpCHchHCwbmQDV299': "utils/__init__.py",
        '1-c3vs68eYuBrdaj0Emim46aGVz4xdeUW': "utils/pose_utils.py",
        '1-YX63uppCMtOwxXfQta9z97AihtWQpY8': "utils/plotting.py",
        '1-bViGma06XmSbJGYddfeofFP8LXqi1bQ': "utils/train_options.py",
        '1-8vm2jmtbGpquuw-FHuaBRTz2P7ItrMb': "hourglass.py",
        '1-Pdkc9DMm-d1eJaOuXtJTXrgFsqZCE1W': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/keypoint', exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))
            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                image=batch['image']
                heat_map=batch['keypoint_heatmaps']
                self.optimizer.zero_grad()
                pred_heatmap_list=self.model(image)
                loss=self.heatmap_loss(pred_heatmap_list[0],heat_map)
                loss.backward()
                self.optimizer.step()

                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    image=batch['image']
                    heat_map=batch['keypoint_heatmaps']
                    pred_heatmap_list=self.model(image)
                    loss=self.heatmap_loss(pred_heatmap_list[0],heat_map).item()

                    self.save_summaries(batch, pred_heatmap_list[-1], loss, mode='test')

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/keypoint/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2020-hw8/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000002 - Remaining Time 0.000951
# Epoch 2/400 - Elapsed Time 4.526153 - Remaining Time 900.704417
# Epoch 3/400 - Elapsed Time 8.812854 - Remaining Time 1166.234321
# Epoch 4/400 - Elapsed Time 13.103015 - Remaining Time 1297.198456
# Epoch 5/400 - Elapsed Time 17.379921 - Remaining Time 1373.013756
# Epoch 6/400 - Elapsed Time 21.747811 - Remaining Time 1428.106245
# Epoch 7/400 - Elapsed Time 26.128237 - Remaining Time 1466.913905
# Epoch 8/400 - Elapsed Time 30.556621 - Remaining Time 1497.274444
# Epoch 9/400 - Elapsed Time 34.910913 - Remaining Time 1516.685199
# Epoch 10/400 - Elapsed Time 39.215426 - Remaining Time 1529.401631
# Epoch 11/400 - Elapsed Time 43.588816 - Remaining Time 1541.459036
# Epoch 12/400 - Elapsed Time 48.240974 - Remaining Time 1559.791491
# Epoch 13/400 - Elapsed Time 52.654720 - Remaining Time 1567.490520
# Epoch 14/400 - Elapsed Time 56.967179 - Remaining Time 1570.666495
# Epoch 15/400 - Elapsed Time 61.280700 - Remaining Time 1572.871293
# Epoch 16/400 - Elapsed Time 65.620848 - Remaining Time 1574.900351
# Epoch 17/400 - Elapsed Time 69.989540 - Remaining Time 1576.823163
# Epoch 18/400 - Elapsed Time 74.355184 - Remaining Time 1577.982230
# Epoch 19/400 - Elapsed Time 78.713567 - Remaining Time 1578.414169
# Epoch 20/400 - Elapsed Time 83.083176 - Remaining Time 1578.580347
# Epoch 21/400 - Elapsed Time 87.396472 - Remaining Time 1577.298241
# Epoch 22/400 - Elapsed Time 91.722154 - Remaining Time 1575.953376
# Epoch 23/400 - Elapsed Time 96.284046 - Remaining Time 1578.221109
# Epoch 24/400 - Elapsed Time 100.614257 - Remaining Time 1576.290020
# Epoch 25/400 - Elapsed Time 105.056027 - Remaining Time 1575.840400
# Epoch 26/400 - Elapsed Time 109.488185 - Remaining Time 1574.945426
# Epoch 27/400 - Elapsed Time 113.801996 - Remaining Time 1572.153503
# Epoch 28/400 - Elapsed Time 118.131874 - Remaining Time 1569.466324
# Epoch 29/400 - Elapsed Time 122.420834 - Remaining Time 1566.142394
# Epoch 30/400 - Elapsed Time 126.740367 - Remaining Time 1563.131192
# Epoch 31/400 - Elapsed Time 131.079844 - Remaining Time 1560.272985
# Epoch 32/400 - Elapsed Time 135.390484 - Remaining Time 1556.990570
# Epoch 33/400 - Elapsed Time 139.909061 - Remaining Time 1555.958342
# Epoch 34/400 - Elapsed Time 144.223599 - Remaining Time 1552.524629
# Epoch 35/400 - Elapsed Time 148.457962 - Remaining Time 1548.204461
# Epoch 36/400 - Elapsed Time 152.779024 - Remaining Time 1544.765688
# Epoch 37/400 - Elapsed Time 157.109824 - Remaining Time 1541.374762
# Epoch 38/400 - Elapsed Time 161.464072 - Remaining Time 1538.157741
# Epoch 290/400 - Elapsed Time 1214.113880 - Remaining Time 460.525955
# Epoch 291/400 - Elapsed Time 1218.210231 - Remaining Time 456.305551
# Epoch 292/400 - Elapsed Time 1222.334044 - Remaining Time 452.096153
# Epoch 293/400 - Elapsed Time 1226.511690 - Remaining Time 447.906999
# Epoch 294/400 - Elapsed Time 1230.588877 - Remaining Time 443.681704
# Epoch 295/400 - Elapsed Time 1234.787799 - Remaining Time 439.500742
# Epoch 296/400 - Elapsed Time 1239.141433 - Remaining Time 435.374017
# Epoch 297/400 - Elapsed Time 1243.174484 - Remaining Time 431.134585
# Epoch 298/400 - Elapsed Time 1247.274294 - Remaining Time 426.919389
# Epoch 299/400 - Elapsed Time 1251.304644 - Remaining Time 422.681502
# Epoch 300/400 - Elapsed Time 1255.383945 - Remaining Time 418.461315
# Epoch 301/400 - Elapsed Time 1259.536363 - Remaining Time 414.266113
# Epoch 302/400 - Elapsed Time 1263.620446 - Remaining Time 410.049019
# Epoch 303/400 - Elapsed Time 1267.709789 - Remaining Time 405.834487
# Epoch 304/400 - Elapsed Time 1271.782042 - Remaining Time 401.615382
# Epoch 305/400 - Elapsed Time 1275.816867 - Remaining Time 397.385582
# Epoch 306/400 - Elapsed Time 1279.859540 - Remaining Time 393.159466
# Epoch 307/400 - Elapsed Time 1284.216489 - Remaining Time 389.029751
# Epoch 308/400 - Elapsed Time 1288.234989 - Remaining Time 384.797464
# Epoch 309/400 - Elapsed Time 1292.294935 - Remaining Time 380.578767
# Epoch 310/400 - Elapsed Time 1296.390318 - Remaining Time 376.371383
# Epoch 311/400 - Elapsed Time 1300.461413 - Remaining Time 372.157768
# Epoch 312/400 - Elapsed Time 1304.531205 - Remaining Time 367.944699
# Epoch 313/400 - Elapsed Time 1308.622172 - Remaining Time 363.738431
# Epoch 314/400 - Elapsed Time 1312.687368 - Remaining Time 359.525840
# Epoch 315/400 - Elapsed Time 1316.790335 - Remaining Time 355.324376
# Epoch 316/400 - Elapsed Time 1320.916167 - Remaining Time 351.129614
# Epoch 317/400 - Elapsed Time 1326.841621 - Remaining Time 347.406481
# Epoch 318/400 - Elapsed Time 1330.913135 - Remaining Time 343.191437
# Epoch 319/400 - Elapsed Time 1335.024196 - Remaining Time 338.987335
# Epoch 320/400 - Elapsed Time 1339.168749 - Remaining Time 334.792187
# Epoch 321/400 - Elapsed Time 1343.210444 - Remaining Time 330.572041
# Epoch 322/400 - Elapsed Time 1347.292098 - Remaining Time 326.362682
# Epoch 323/400 - Elapsed Time 1351.351174 - Remaining Time 322.148732
# Epoch 324/400 - Elapsed Time 1355.489945 - Remaining Time 317.954431
# Epoch 325/400 - Elapsed Time 1359.542141 - Remaining Time 313.740494
# Epoch 326/400 - Elapsed Time 1363.658295 - Remaining Time 309.542067
# Epoch 327/400 - Elapsed Time 1367.698684 - Remaining Time 305.327229
# Epoch 328/400 - Elapsed Time 1372.042872 - Remaining Time 301.180143
# Epoch 329/400 - Elapsed Time 1376.120005 - Remaining Time 296.974226
# Epoch 330/400 - Elapsed Time 1380.107883 - Remaining Time 292.750157
# Epoch 331/400 - Elapsed Time 1384.182399 - Remaining Time 288.545576
# Epoch 332/400 - Elapsed Time 1388.250783 - Remaining Time 284.340522
# Epoch 333/400 - Elapsed Time 1392.331412 - Remaining Time 280.138753
# Epoch 334/400 - Elapsed Time 1396.435748 - Remaining Time 275.942393
# Epoch 335/400 - Elapsed Time 1400.537944 - Remaining Time 271.746168
# Epoch 336/400 - Elapsed Time 1404.695942 - Remaining Time 267.561132
# Epoch 337/400 - Elapsed Time 1408.683509 - Remaining Time 263.344395
# Epoch 338/400 - Elapsed Time 1412.942887 - Remaining Time 259.178873
# Epoch 339/400 - Elapsed Time 1416.997342 - Remaining Time 254.975923
# Epoch 340/400 - Elapsed Time 1421.095937 - Remaining Time 250.781636
# Epoch 341/400 - Elapsed Time 1425.170993 - Remaining Time 246.583837
# Epoch 342/400 - Elapsed Time 1429.294259 - Remaining Time 242.394933
# Epoch 343/400 - Elapsed Time 1433.312065 - Remaining Time 238.188885
# Epoch 344/400 - Elapsed Time 1437.356311 - Remaining Time 233.988237
# Epoch 345/400 - Elapsed Time 1441.419592 - Remaining Time 229.791529
# Epoch 346/400 - Elapsed Time 1445.516867 - Remaining Time 225.600898
# Epoch 347/400 - Elapsed Time 1449.562366 - Remaining Time 221.402897
# Epoch 348/400 - Elapsed Time 1453.641995 - Remaining Time 217.210873
# Epoch 349/400 - Elapsed Time 1457.933018 - Remaining Time 213.050384
# Epoch 350/400 - Elapsed Time 1461.976232 - Remaining Time 208.853747
# Epoch 351/400 - Elapsed Time 1466.020711 - Remaining Time 204.658162
# Epoch 352/400 - Elapsed Time 1470.067023 - Remaining Time 200.463685
# Epoch 353/400 - Elapsed Time 1474.152413 - Remaining Time 196.275250
# Epoch 354/400 - Elapsed Time 1478.236326 - Remaining Time 192.087206
# Epoch 355/400 - Elapsed Time 1482.265168 - Remaining Time 187.892768
# Epoch 356/400 - Elapsed Time 1486.297652 - Remaining Time 183.699710
# Epoch 357/400 - Elapsed Time 1490.308916 - Remaining Time 179.504995
# Epoch 358/400 - Elapsed Time 1494.424293 - Remaining Time 175.323520
# Epoch 359/400 - Elapsed Time 1498.668388 - Remaining Time 171.157114
# Epoch 360/400 - Elapsed Time 1502.726121 - Remaining Time 166.969569
# Epoch 361/400 - Elapsed Time 1506.760901 - Remaining Time 162.780264
# Epoch 362/400 - Elapsed Time 1510.848209 - Remaining Time 158.597326
# Epoch 363/400 - Elapsed Time 1514.908334 - Remaining Time 154.412144
# Epoch 364/400 - Elapsed Time 1518.882530 - Remaining Time 150.219151
# Epoch 365/400 - Elapsed Time 1522.908475 - Remaining Time 146.032320
# Epoch 366/400 - Elapsed Time 1526.874806 - Remaining Time 141.840829
# Epoch 367/400 - Elapsed Time 1530.958223 - Remaining Time 137.661094
# Epoch 368/400 - Elapsed Time 1535.073924 - Remaining Time 133.484689
# Epoch 369/400 - Elapsed Time 1539.200976 - Remaining Time 129.309567
# Epoch 370/400 - Elapsed Time 1545.136886 - Remaining Time 125.281369
# Epoch 371/400 - Elapsed Time 1549.635314 - Remaining Time 121.130523
# Epoch 372/400 - Elapsed Time 1554.358449 - Remaining Time 116.994722
# Epoch 373/400 - Elapsed Time 1558.497048 - Remaining Time 112.813459
# Epoch 374/400 - Elapsed Time 1562.599602 - Remaining Time 108.629919
# Epoch 375/400 - Elapsed Time 1566.619153 - Remaining Time 104.441277
# Epoch 376/400 - Elapsed Time 1570.726659 - Remaining Time 100.259148
# Epoch 377/400 - Elapsed Time 1574.861227 - Remaining Time 96.079067
# Epoch 378/400 - Elapsed Time 1578.910807 - Remaining Time 91.894280
# Epoch 379/400 - Elapsed Time 1582.951512 - Remaining Time 87.709714
# Epoch 380/400 - Elapsed Time 1587.202420 - Remaining Time 83.536969
# Epoch 381/400 - Elapsed Time 1591.278435 - Remaining Time 79.355093
# Epoch 382/400 - Elapsed Time 1595.452136 - Remaining Time 75.178373
# Epoch 383/400 - Elapsed Time 1599.528628 - Remaining Time 70.997354
# Epoch 384/400 - Elapsed Time 1603.580626 - Remaining Time 66.815859
# Epoch 385/400 - Elapsed Time 1607.702229 - Remaining Time 62.637749
# Epoch 386/400 - Elapsed Time 1611.770452 - Remaining Time 58.457996
# Epoch 387/400 - Elapsed Time 1615.871578 - Remaining Time 54.279924
# Epoch 388/400 - Elapsed Time 1619.916929 - Remaining Time 50.100524
# Epoch 389/400 - Elapsed Time 1623.980408 - Remaining Time 45.922325
# Epoch 390/400 - Elapsed Time 1628.008036 - Remaining Time 41.743796
# Epoch 391/400 - Elapsed Time 1632.405986 - Remaining Time 37.574562
# Epoch 392/400 - Elapsed Time 1636.522107 - Remaining Time 33.398410
# Epoch 393/400 - Elapsed Time 1640.643804 - Remaining Time 29.222663
# Epoch 394/400 - Elapsed Time 1644.717524 - Remaining Time 25.046460
# Epoch 395/400 - Elapsed Time 1648.780616 - Remaining Time 20.870641
# Epoch 396/400 - Elapsed Time 1652.824994 - Remaining Time 16.695202
# Epoch 397/400 - Elapsed Time 1656.835702 - Remaining Time 12.520169
# Epoch 398/400 - Elapsed Time 1660.895411 - Remaining Time 8.346208
# Epoch 399/400 - Elapsed Time 1664.948469 - Remaining Time 4.172803
# Epoch 400/400 - Elapsed Time 1668.972791 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2020-hw8/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2020-hw8/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 39.13it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert fom axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: 
image
vertices: mesh vertices
faces: mesh faces, 
keypoints_2d: detected 2d keypoints,
conf: keypoint confidences
keypoints_3d: 3D keypoint coordinates in the canonical position, 
K: intrinsic camera matrix.

Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d = conf.sqrt()[:, None]
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]

    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)
    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100
    Loss=nn.MSELoss()
    i=0
    while not converged:
      optimizer.zero_grad()
      # convert axis-angle to rotation matrix
      R = rodrigues(r)
      # 1) Compute projected keypoints based on current estimate of R and t
      # 2) Compute error (based on distance between projected keypoints and detected keypoints)
      # 3) Update based on error
      # 4) Check for convergence
      a=torch.matmul(R,torch.transpose(keypoints_3d,0,1))
      a=a+t.view(3,1)
      b=a
      c=b[:-1,:]/(b[-1,:].view(1,10))
      D=torch.sqrt(torch.diag(conf))
      loss=torch.transpose(norm_keypoints_2d,0,1)-c
      obj=torch.matmul(loss,D)
      target=torch.zeros(2,10)
      l=Loss(obj,target)
      l.backward()
      if i%3000==2999:
        print(l.item())
      i+=1
      optimizer.step()

      converged=(np.abs(l.item()-loss_old)/loss_old)<rel_tol
      loss_old=l.item()


    proj_keypoints=c.t()
    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    pk = torch.matmul(K, torch.cat((proj_keypoints, torch.ones(proj_keypoints.shape[0], 1, device=device)), dim=-1).t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

# %%
"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):
    n,_,_,_=heatmaps.shape
    output=torch.zeros(n,10,3)
    for i in range(n):
      for j in range(10):
        location=torch.argmax(heatmaps[i][j]).item()
        maxvalue=torch.max(heatmaps[i][j])
        a=location//64
        b=location%64
        output[i][j][0]=b
        output[i][j][1]=a
        output[i][j][2]=maxvalue
    return output
    pass

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2020-hw8/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')


os.makedirs('/content/gdrive/My Drive/cis580-2020-hw8/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    # Fixes incorrect naming scheme
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2020-hw8/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# Processing  train_160.jpg
# Processing  train_80.jpg
# 8.47490991873201e-06
# Processing  train_181.jpg
# Processing  train_176.jpg
# Processing  train_2.jpg
# 0.7017134428024292
# 0.5923332571983337
# Processing  train_155.jpg
# Processing  train_136.jpg
# 0.0004427813983056694
# 1.4778253898839466e-05
# Processing  train_4.jpg
# Processing  train_18.jpg
# 1.0867235660552979
# 0.7978745698928833
# Processing  train_106.jpg
# Processing  train_90.jpg
# 0.10137990862131119
# 0.06960062682628632
# 0.040737152099609375
# 0.013551300391554832
# 0.003967187833040953
# 0.0008624285692349076
# 9.854613745119423e-05
# Processing  train_25.jpg
# Processing  train_116.jpg
# 1.5251169315888546e-05
# Processing  train_190.jpg
# Processing  train_177.jpg
# Processing  train_52.jpg
# Processing  train_191.jpg
# Processing  train_13.jpg
# Processing  train_9.jpg
# 0.010751459747552872
# 0.0015003528678789735
# 9.855038661044091e-05
# Processing  train_81.jpg
# 1.3487873729900457e-05
# Processing  train_21.jpg
# Processing  train_72.jpg
# Processing  train_144.jpg
# 2.440172465867363e-05
# Processing  train_10.jpg
# Processing  train_12.jpg
# Processing  train_140.jpg
# 0.9802020788192749
